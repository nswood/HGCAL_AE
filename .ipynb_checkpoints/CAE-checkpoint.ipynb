# %%
import os
import sys
import pandas as pd
import torch.nn as nn
import torch.optim as optim
import numpy as np
import torch
import matplotlib.pyplot as plt
import AE_Stats
from load_data_fn import load_data,load_data_no_filter

from torch.autograd import Variable
from torch.utils.data import Dataset, DataLoader, TensorDataset
import importlib
import time

from losses import *
from telescope_torch import *

# %%
import train_CAE

# %%
data_path = '/uscms/home/nswood/nobackup/Notebooks/AE_Dev/MIT_TTbar'
all_files = os.listdir(data_path)
dt_files = []
for f in all_files:
    if f[0:7] == 'dt_norm' and (f[-3:] != 'low' and f[-4:] !='high'):
        dt_files.append(f)

# %%
importlib.reload(train_CAE)
train_CAE.train_CAEs(data_path,
              dt_files,
               model_params = [],
              override = False ,
              loss = combo_loss, 
              path_1 = 'models/CAE_Models/dt_1_250_150',
              path_2 = 'models/CAE_Models/dt_2_250_150',
              path_3 = 'models/CAE_Models/dt_3_250_150',
             dir_label ='CAE_combo_loss_250_150',
             epochs= 101,
             batch = 20, 
             lr = 8.5e-4)
# Out:
# TRAINING MODEL dt_norm_3_36
# dt_norm_3_36
# /uscms/home/nswood/nobackup/Notebooks/AE_Dev/models/batched_models/CAE_combo_loss_250_150/dt_norm_3_36
# TRAINING INFO:
# Total Dataset Size: 38509
# Epoch 0, lr 0.00085
# Epoch 0: Train 0.339, Test 0.288
# MSE NON-NORMALIZED: Train MSE 7.012, Test MSE 4.838
# Epoch 25, lr 0.00085
# Epoch 25: Train 0.239, Test 0.288
# MSE NON-NORMALIZED: Train MSE 5.238, Test MSE 4.837
# Epoch 50, lr 0.00010625
# Epoch 50: Train 0.235, Test 0.237
# MSE NON-NORMALIZED: Train MSE 4.126, Test MSE 3.832
# Epoch 75, lr 2.65625e-05
# Epoch 75: Train 0.242, Test 0.233
# MSE NON-NORMALIZED: Train MSE 4.177, Test MSE 6.786
# Epoch 100, lr 6.640625e-06
# Epoch 100: Train 0.244, Test 0.233
# MSE NON-NORMALIZED: Train MSE 4.292, Test MSE 9.296
# TRAINING MODEL dt_norm_3_30
# dt_norm_3_30
# /uscms/home/nswood/nobackup/Notebooks/AE_Dev/models/batched_models/CAE_combo_loss_250_150/dt_norm_3_30
# TRAINING INFO:
# Total Dataset Size: 40000
# Epoch 0, lr 0.00085
# Epoch 0: Train 0.568, Test 0.858
# MSE NON-NORMALIZED: Train MSE 28.632, Test MSE 23.089
# Epoch 25, lr 0.000425
# Epoch 25: Train 0.216, Test 0.474
# MSE NON-NORMALIZED: Train MSE 11.354, Test MSE 10.469
# Epoch 50, lr 0.0002125
# Epoch 50: Train 0.201, Test 0.434
# MSE NON-NORMALIZED: Train MSE 9.994, Test MSE 9.432
# Epoch 75, lr 5.3125e-05
# Epoch 75: Train 0.194, Test 0.383
# MSE NON-NORMALIZED: Train MSE 8.831, Test MSE 14.177
# Epoch 100, lr 1.328125e-05
# Epoch 100: Train 0.193, Test 0.382
# MSE NON-NORMALIZED: Train MSE 9.043, Test MSE 19.971
# TRAINING MODEL dt_norm_3_31
# dt_norm_3_31
# /uscms/home/nswood/nobackup/Notebooks/AE_Dev/models/batched_models/CAE_combo_loss_250_150/dt_norm_3_31
# TRAINING INFO:
# Total Dataset Size: 40000
# Epoch 0, lr 0.00085
# Epoch 0: Train 0.861, Test 0.664
# MSE NON-NORMALIZED: Train MSE 64.274, Test MSE 16.284
# Epoch 25, lr 0.00085
# Epoch 25: Train 0.699, Test 1.038
# MSE NON-NORMALIZED: Train MSE 28.448, Test MSE 22.560
# Epoch 50, lr 0.000425
# Epoch 50: Train 0.483, Test 0.550
# MSE NON-NORMALIZED: Train MSE 12.235, Test MSE 11.167
# Epoch 75, lr 0.0002125
# Epoch 75: Train 0.412, Test 0.374
# MSE NON-NORMALIZED: Train MSE 8.734, Test MSE 14.670
# Epoch 100, lr 5.3125e-05
# Epoch 100: Train 0.384, Test 0.345
# MSE NON-NORMALIZED: Train MSE 8.195, Test MSE 19.635
# TRAINING MODEL dt_norm_3_33
# dt_norm_3_33
# /uscms/home/nswood/nobackup/Notebooks/AE_Dev/models/batched_models/CAE_combo_loss_250_150/dt_norm_3_33
# TRAINING INFO:
# Total Dataset Size: 40000
# Epoch 0, lr 0.00085
# Epoch 0: Train 0.600, Test 1.524
# MSE NON-NORMALIZED: Train MSE 44.017, Test MSE 53.761
# Epoch 25, lr 0.000425
# Epoch 25: Train 0.209, Test 0.725
# MSE NON-NORMALIZED: Train MSE 17.144, Test MSE 16.573
# Epoch 50, lr 0.0002125
# Epoch 50: Train 0.151, Test 0.280
# MSE NON-NORMALIZED: Train MSE 6.166, Test MSE 5.211
# Epoch 75, lr 0.00010625
# Epoch 75: Train 0.145, Test 0.263
# MSE NON-NORMALIZED: Train MSE 5.834, Test MSE 9.599
# Epoch 100, lr 2.65625e-05
# Epoch 100: Train 0.143, Test 0.257
# MSE NON-NORMALIZED: Train MSE 5.854, Test MSE 13.766
# TRAINING MODEL dt_norm_3_35
# dt_norm_3_35
# /uscms/home/nswood/nobackup/Notebooks/AE_Dev/models/batched_models/CAE_combo_loss_250_150/dt_norm_3_35
# TRAINING INFO:
# Total Dataset Size: 40000
# Epoch 0, lr 0.00085
# Epoch 0: Train 0.559, Test 0.444
# MSE NON-NORMALIZED: Train MSE 8.297, Test MSE 8.061
# Epoch 25, lr 0.00085
# Epoch 25: Train 0.391, Test 0.343
# MSE NON-NORMALIZED: Train MSE 6.351, Test MSE 6.072
# Epoch 50, lr 0.000425
# Epoch 50: Train 0.362, Test 0.325
# MSE NON-NORMALIZED: Train MSE 5.978, Test MSE 5.741
# Epoch 75, lr 5.3125e-05
# Epoch 75: Train 0.350, Test 0.312
# MSE NON-NORMALIZED: Train MSE 5.965, Test MSE 9.751
# Epoch 100, lr 1.328125e-05
# Epoch 100: Train 0.339, Test 0.308
# MSE NON-NORMALIZED: Train MSE 6.085, Test MSE 13.319
# TRAINING MODEL dt_norm_3_37
# dt_norm_3_37
# /uscms/home/nswood/nobackup/Notebooks/AE_Dev/models/batched_models/CAE_combo_loss_250_150/dt_norm_3_37
# TRAINING INFO:
# Total Dataset Size: 39700
# Epoch 0, lr 0.00085
# Epoch 0: Train 0.362, Test 0.644
# MSE NON-NORMALIZED: Train MSE 6.359, Test MSE 17.798
# Epoch 25, lr 0.000425
# Epoch 25: Train 0.221, Test 0.222
# MSE NON-NORMALIZED: Train MSE 4.373, Test MSE 3.888
# Epoch 50, lr 0.000425
# Epoch 50: Train 0.181, Test 0.206
# MSE NON-NORMALIZED: Train MSE 3.694, Test MSE 3.465
# Epoch 75, lr 0.00010625
# Epoch 75: Train 0.174, Test 0.199
# MSE NON-NORMALIZED: Train MSE 3.644, Test MSE 6.659
# Epoch 100, lr 1.328125e-05
# Epoch 100: Train 0.175, Test 0.198
# MSE NON-NORMALIZED: Train MSE 3.739, Test MSE 9.295
# TRAINING MODEL dt_norm_3_27
# dt_norm_3_27
# /uscms/home/nswood/nobackup/Notebooks/AE_Dev/models/batched_models/CAE_combo_loss_250_150/dt_norm_3_27
# TRAINING INFO:
# Total Dataset Size: 38512
# Epoch 0, lr 0.00085
# Epoch 0: Train 0.595, Test 0.683
# MSE NON-NORMALIZED: Train MSE 29.519, Test MSE 14.856
# Epoch 25, lr 0.00085
# Epoch 25: Train 0.553, Test 0.672
# MSE NON-NORMALIZED: Train MSE 18.480, Test MSE 13.841
# Epoch 50, lr 0.000425
# Epoch 50: Train 0.536, Test 0.529
# MSE NON-NORMALIZED: Train MSE 12.239, Test MSE 10.686
# Epoch 75, lr 0.00010625
# Epoch 75: Train 0.430, Test 0.358
# MSE NON-NORMALIZED: Train MSE 8.628, Test MSE 14.348
# Epoch 100, lr 0.00010625
# Epoch 100: Train 0.412, Test 0.354
# MSE NON-NORMALIZED: Train MSE 8.876, Test MSE 20.685
# TRAINING MODEL dt_norm_3_29
# dt_norm_3_29
# /uscms/home/nswood/nobackup/Notebooks/AE_Dev/models/batched_models/CAE_combo_loss_250_150/dt_norm_3_29
# TRAINING INFO:
# Total Dataset Size: 40000
# Epoch 0, lr 0.00085
# Epoch 0: Train 28.340, Test 2.146
# MSE NON-NORMALIZED: Train MSE 54.744, Test MSE 113.402
# Epoch 25, lr 0.000425
# Epoch 25: Train 0.543, Test 0.377
# MSE NON-NORMALIZED: Train MSE 8.258, Test MSE 7.346
# Epoch 50, lr 0.0002125
# Epoch 50: Train 0.457, Test 0.328
# MSE NON-NORMALIZED: Train MSE 6.794, Test MSE 6.112
# Epoch 75, lr 0.00010625
# Epoch 75: Train 0.433, Test 0.316
# MSE NON-NORMALIZED: Train MSE 6.636, Test MSE 10.960
# Epoch 100, lr 2.65625e-05
# Epoch 100: Train 0.427, Test 0.312
# MSE NON-NORMALIZED: Train MSE 6.719, Test MSE 15.620
# TRAINING MODEL dt_norm_3_32
# dt_norm_3_32
# /uscms/home/nswood/nobackup/Notebooks/AE_Dev/models/batched_models/CAE_combo_loss_250_150/dt_norm_3_32
# TRAINING INFO:
# Total Dataset Size: 40000
# Epoch 0, lr 0.00085
# Epoch 0: Train 0.439, Test 0.568
# MSE NON-NORMALIZED: Train MSE 11.823, Test MSE 12.050
# Epoch 25, lr 0.000425
# Epoch 25: Train 0.176, Test 0.342
# MSE NON-NORMALIZED: Train MSE 7.025, Test MSE 6.713
# Epoch 50, lr 0.0002125
# Epoch 50: Train 0.157, Test 0.325
# MSE NON-NORMALIZED: Train MSE 6.634, Test MSE 6.339
# Epoch 75, lr 5.3125e-05
# Epoch 75: Train 0.143, Test 0.305
# MSE NON-NORMALIZED: Train MSE 6.589, Test MSE 11.416
# Epoch 100, lr 1.328125e-05
# Epoch 100: Train 0.139, Test 0.304
# MSE NON-NORMALIZED: Train MSE 6.778, Test MSE 16.467
# TRAINING MODEL dt_norm_3_34
# dt_norm_3_34
# /uscms/home/nswood/nobackup/Notebooks/AE_Dev/models/batched_models/CAE_combo_loss_250_150/dt_norm_3_34
# TRAINING INFO:
# Total Dataset Size: 40000
# Epoch 0, lr 0.00085
# Epoch 0: Train 0.626, Test 12.086
# MSE NON-NORMALIZED: Train MSE 783.633, Test MSE 1424.402
# Epoch 25, lr 0.0002125
# Epoch 25: Train 1.123, Test 1.998
# MSE NON-NORMALIZED: Train MSE 40.056, Test MSE 51.728
# Epoch 50, lr 5.3125e-05
# Epoch 50: Train 0.822, Test 0.989
# MSE NON-NORMALIZED: Train MSE 20.961, Test MSE 20.325
# Epoch 75, lr 1.328125e-05
# Epoch 75: Train 0.826, Test 0.356
# MSE NON-NORMALIZED: Train MSE 6.969, Test MSE 10.695
# Epoch 100, lr 1.66015625e-06
# Epoch 100: Train 0.779, Test 0.342
# MSE NON-NORMALIZED: Train MSE 6.875, Test MSE 14.426
# TRAINING MODEL dt_norm_3_38
# dt_norm_3_38
# /uscms/home/nswood/nobackup/Notebooks/AE_Dev/models/batched_models/CAE_combo_loss_250_150/dt_norm_3_38
# TRAINING INFO:
# Total Dataset Size: 33267
# Epoch 0, lr 0.00085
# Epoch 0: Train 0.314, Test 0.407
# MSE NON-NORMALIZED: Train MSE 8.304, Test MSE 8.956
# Epoch 25, lr 0.000425
# Epoch 25: Train 0.135, Test 0.289
# MSE NON-NORMALIZED: Train MSE 4.836, Test MSE 5.666
# Epoch 50, lr 0.0002125
# Epoch 50: Train 0.104, Test 0.227
# MSE NON-NORMALIZED: Train MSE 4.078, Test MSE 4.046
# Epoch 75, lr 0.00010625
# Epoch 75: Train 0.090, Test 0.215
# MSE NON-NORMALIZED: Train MSE 4.091, Test MSE 7.378
# Epoch 100, lr 1.328125e-05
# Epoch 100: Train 0.086, Test 0.210
# MSE NON-NORMALIZED: Train MSE 4.186, Test MSE 10.385
# TRAINING MODEL dt_norm_1_1
# dt_norm_1_1
# /uscms/home/nswood/nobackup/Notebooks/AE_Dev/models/batched_models/CAE_combo_loss_250_150/dt_norm_1_1
# TRAINING INFO:
# Total Dataset Size: 40000
# Epoch 0, lr 0.00085
# Epoch 0: Train 0.834, Test 1.189
# MSE NON-NORMALIZED: Train MSE 64.245, Test MSE 38.068
# Epoch 25, lr 0.00085
# Epoch 25: Train 0.252, Test 0.344
# MSE NON-NORMALIZED: Train MSE 23.319, Test MSE 12.557
# Epoch 50, lr 0.000425
# Epoch 50: Train 0.176, Test 0.255
# MSE NON-NORMALIZED: Train MSE 12.630, Test MSE 8.950
# Epoch 75, lr 0.0002125
# Epoch 75: Train 0.153, Test 0.218
# MSE NON-NORMALIZED: Train MSE 10.094, Test MSE 12.224
# Epoch 100, lr 5.3125e-05
# Epoch 100: Train 0.144, Test 0.202
# MSE NON-NORMALIZED: Train MSE 9.030, Test MSE 14.172
# TRAINING MODEL dt_norm_1_3
# dt_norm_1_3
# /uscms/home/nswood/nobackup/Notebooks/AE_Dev/models/batched_models/CAE_combo_loss_250_150/dt_norm_1_3
# TRAINING INFO:
# Total Dataset Size: 40000
# Epoch 0, lr 0.00085
# Epoch 0: Train 8.342, Test 9.255
# MSE NON-NORMALIZED: Train MSE 301.147, Test MSE 324.216
# Epoch 25, lr 0.00085
# Epoch 25: Train 6.321, Test 5.713
# MSE NON-NORMALIZED: Train MSE 183.077, Test MSE 162.821
# Epoch 50, lr 0.000425
# Epoch 50: Train 6.556, Test 6.087
# MSE NON-NORMALIZED: Train MSE 169.822, Test MSE 185.823
# Epoch 75, lr 0.0002125
# Epoch 75: Train 5.277, Test 4.520
# MSE NON-NORMALIZED: Train MSE 129.620, Test MSE 126.703
# Epoch 100, lr 0.0002125
# Epoch 100: Train 5.084, Test 4.331
# MSE NON-NORMALIZED: Train MSE 125.258, Test MSE 124.829
# TRAINING MODEL dt_norm_1_5
# dt_norm_1_5
# /uscms/home/nswood/nobackup/Notebooks/AE_Dev/models/batched_models/CAE_combo_loss_250_150/dt_norm_1_5
# TRAINING INFO:
# Total Dataset Size: 40000
# Epoch 0, lr 0.00085
# Epoch 0: Train 10.521, Test 11.290
# MSE NON-NORMALIZED: Train MSE 543.882, Test MSE 491.871
# Epoch 25, lr 0.00085
# Epoch 25: Train 7.464, Test 7.576
# MSE NON-NORMALIZED: Train MSE 307.481, Test MSE 252.505
# Epoch 50, lr 0.000425
# Epoch 50: Train 6.419, Test 6.556
# MSE NON-NORMALIZED: Train MSE 210.865, Test MSE 201.962
# Epoch 75, lr 0.000425
# Epoch 75: Train 5.735, Test 6.052
# MSE NON-NORMALIZED: Train MSE 207.935, Test MSE 195.624
# Epoch 100, lr 0.0002125
# Epoch 100: Train 5.039, Test 5.336
# MSE NON-NORMALIZED: Train MSE 169.279, Test MSE 165.356
# TRAINING MODEL dt_norm_1_7
# dt_norm_1_7
# /uscms/home/nswood/nobackup/Notebooks/AE_Dev/models/batched_models/CAE_combo_loss_250_150/dt_norm_1_7
# TRAINING INFO:
# Total Dataset Size: 40000
# Epoch 0, lr 0.00085
# Epoch 0: Train 8.837, Test 11.228
# MSE NON-NORMALIZED: Train MSE 653.812, Test MSE 537.880
# Epoch 25, lr 0.00085
# Epoch 25: Train 6.685, Test 7.156
# MSE NON-NORMALIZED: Train MSE 343.733, Test MSE 261.252
# Epoch 50, lr 0.000425
# Epoch 50: Train 5.637, Test 5.755
# MSE NON-NORMALIZED: Train MSE 210.352, Test MSE 185.908
# Epoch 75, lr 0.000425
# Epoch 75: Train 5.893, Test 5.783
# MSE NON-NORMALIZED: Train MSE 208.255, Test MSE 202.121
# Epoch 100, lr 0.0002125
# Epoch 100: Train 4.884, Test 4.847
# MSE NON-NORMALIZED: Train MSE 163.878, Test MSE 157.957
# TRAINING MODEL dt_norm_1_9
# dt_norm_1_9
# /uscms/home/nswood/nobackup/Notebooks/AE_Dev/models/batched_models/CAE_combo_loss_250_150/dt_norm_1_9
# TRAINING INFO:
# Total Dataset Size: 40000
# Epoch 0, lr 0.00085
# Epoch 0: Train 15.292, Test 7.128
# MSE NON-NORMALIZED: Train MSE 512.018, Test MSE 292.639
# Epoch 25, lr 0.000425
# Epoch 25: Train 7.068, Test 4.507
# MSE NON-NORMALIZED: Train MSE 176.820, Test MSE 138.670
# Epoch 50, lr 0.0002125
# Epoch 50: Train 4.993, Test 3.849
# MSE NON-NORMALIZED: Train MSE 132.549, Test MSE 110.528
# Epoch 75, lr 0.00010625
# Epoch 75: Train 3.404, Test 3.475
# MSE NON-NORMALIZED: Train MSE 107.255, Test MSE 102.761
# Epoch 100, lr 5.3125e-05
# Epoch 100: Train 3.128, Test 3.293
# MSE NON-NORMALIZED: Train MSE 93.675, Test MSE 101.906
# TRAINING MODEL dt_norm_1_11
# dt_norm_1_11
# /uscms/home/nswood/nobackup/Notebooks/AE_Dev/models/batched_models/CAE_combo_loss_250_150/dt_norm_1_11
# TRAINING INFO:
# Total Dataset Size: 40000
# Epoch 0, lr 0.00085
# Epoch 0: Train 4.556, Test 5.400
# MSE NON-NORMALIZED: Train MSE 312.030, Test MSE 231.481
# Epoch 25, lr 0.00085
# Epoch 25: Train 3.730, Test 4.231
# MSE NON-NORMALIZED: Train MSE 184.738, Test MSE 142.197
# Epoch 50, lr 0.00085
# Epoch 50: Train 3.462, Test 4.109
# MSE NON-NORMALIZED: Train MSE 149.681, Test MSE 141.144
# Epoch 75, lr 0.000425
# Epoch 75: Train 2.689, Test 3.077
# MSE NON-NORMALIZED: Train MSE 95.654, Test MSE 99.244
# Epoch 100, lr 0.0002125
# Epoch 100: Train 2.377, Test 2.635
# MSE NON-NORMALIZED: Train MSE 76.846, Test MSE 84.724
# TRAINING MODEL dt_norm_1_13
# dt_norm_1_13
# /uscms/home/nswood/nobackup/Notebooks/AE_Dev/models/batched_models/CAE_combo_loss_250_150/dt_norm_1_13
# TRAINING INFO:
# Total Dataset Size: 40000
# Epoch 0, lr 0.00085
# Epoch 0: Train 6.854, Test 4.026
# MSE NON-NORMALIZED: Train MSE 216.257, Test MSE 149.545
# Epoch 25, lr 0.00085
# Epoch 25: Train 4.627, Test 2.909
# MSE NON-NORMALIZED: Train MSE 93.557, Test MSE 95.001
# Epoch 50, lr 0.0002125
# Epoch 50: Train 1.999, Test 1.811
# MSE NON-NORMALIZED: Train MSE 48.883, Test MSE 45.254
# Epoch 75, lr 5.3125e-05
# Epoch 75: Train 1.776, Test 1.674
# MSE NON-NORMALIZED: Train MSE 42.153, Test MSE 47.282
# Epoch 100, lr 5.3125e-05
# Epoch 100: Train 1.723, Test 1.640
# MSE NON-NORMALIZED: Train MSE 41.673, Test MSE 52.212
# TRAINING MODEL dt_norm_1_15
# dt_norm_1_15
# /uscms/home/nswood/nobackup/Notebooks/AE_Dev/models/batched_models/CAE_combo_loss_250_150/dt_norm_1_15
# TRAINING INFO:
# Total Dataset Size: 40000
# Epoch 0, lr 0.00085
# Epoch 0: Train 3.635, Test 6.680
# MSE NON-NORMALIZED: Train MSE 152.164, Test MSE 519.208
# Epoch 25, lr 0.00085
# Epoch 25: Train 2.109, Test 2.081
# MSE NON-NORMALIZED: Train MSE 69.467, Test MSE 64.487
# Epoch 50, lr 0.00085
# Epoch 50: Train 2.060, Test 1.998
# MSE NON-NORMALIZED: Train MSE 64.839, Test MSE 64.102
# Epoch 75, lr 0.000425
# Epoch 75: Train 1.761, Test 1.590
# MSE NON-NORMALIZED: Train MSE 42.396, Test MSE 50.377
# Epoch 100, lr 0.0002125
# Epoch 100: Train 1.652, Test 1.420
# MSE NON-NORMALIZED: Train MSE 36.918, Test MSE 47.438
# TRAINING MODEL dt_norm_1_17
# dt_norm_1_17
# /uscms/home/nswood/nobackup/Notebooks/AE_Dev/models/batched_models/CAE_combo_loss_250_150/dt_norm_1_17
# TRAINING INFO:
# Total Dataset Size: 40000
# Epoch 0, lr 0.00085
# Epoch 0: Train 2.880, Test 3.081
# MSE NON-NORMALIZED: Train MSE 118.647, Test MSE 117.450
# Epoch 25, lr 0.000425
# Epoch 25: Train 1.640, Test 1.418
# MSE NON-NORMALIZED: Train MSE 38.798, Test MSE 38.425
# Epoch 50, lr 0.0002125
# Epoch 50: Train 1.429, Test 1.216
# MSE NON-NORMALIZED: Train MSE 31.073, Test MSE 31.364
# Epoch 75, lr 0.0002125
# Epoch 75: Train 1.297, Test 1.167
# MSE NON-NORMALIZED: Train MSE 30.255, Test MSE 36.870
# Epoch 100, lr 0.00010625
# Epoch 100: Train 1.159, Test 1.080
# MSE NON-NORMALIZED: Train MSE 27.813, Test MSE 38.360
# TRAINING MODEL dt_norm_1_19
# dt_norm_1_19
# /uscms/home/nswood/nobackup/Notebooks/AE_Dev/models/batched_models/CAE_combo_loss_250_150/dt_norm_1_19
# TRAINING INFO:
# Total Dataset Size: 40000
# Epoch 0, lr 0.00085
# Epoch 0: Train 1.948, Test 2.164
# MSE NON-NORMALIZED: Train MSE 89.013, Test MSE 70.063
# Epoch 25, lr 0.00085
# Epoch 25: Train 1.313, Test 1.221
# MSE NON-NORMALIZED: Train MSE 40.587, Test MSE 30.154
# Epoch 50, lr 0.000425
# Epoch 50: Train 1.184, Test 1.135
# MSE NON-NORMALIZED: Train MSE 27.320, Test MSE 27.976
# Epoch 75, lr 0.0002125
# Epoch 75: Train 1.098, Test 1.025
# MSE NON-NORMALIZED: Train MSE 24.219, Test MSE 31.909
# Epoch 100, lr 0.0002125
# Epoch 100: Train 1.073, Test 1.002
# MSE NON-NORMALIZED: Train MSE 24.504, Test MSE 37.235
# TRAINING MODEL dt_norm_1_21
# dt_norm_1_21
# /uscms/home/nswood/nobackup/Notebooks/AE_Dev/models/batched_models/CAE_combo_loss_250_150/dt_norm_1_21
# TRAINING INFO:
# Total Dataset Size: 40000
# Epoch 0, lr 0.00085
# Epoch 0: Train 1.919, Test 1.682
# MSE NON-NORMALIZED: Train MSE 52.647, Test MSE 44.169
# Epoch 25, lr 0.00085
# Epoch 25: Train 1.789, Test 1.235
# MSE NON-NORMALIZED: Train MSE 29.934, Test MSE 29.376
# Epoch 50, lr 0.0002125
# Epoch 50: Train 1.489, Test 0.953
# MSE NON-NORMALIZED: Train MSE 22.671, Test MSE 21.229
# Epoch 75, lr 5.3125e-05
# Epoch 75: Train 1.370, Test 0.857
# MSE NON-NORMALIZED: Train MSE 19.946, Test MSE 26.819
# Epoch 100, lr 1.328125e-05
# Epoch 100: Train 1.365, Test 0.852
# MSE NON-NORMALIZED: Train MSE 20.099, Test MSE 33.580
# TRAINING MODEL dt_norm_1_23
# dt_norm_1_23
# /uscms/home/nswood/nobackup/Notebooks/AE_Dev/models/batched_models/CAE_combo_loss_250_150/dt_norm_1_23
# TRAINING INFO:
# Total Dataset Size: 40000
# Epoch 0, lr 0.00085
# Epoch 0: Train 1.154, Test 1.136
# MSE NON-NORMALIZED: Train MSE 34.236, Test MSE 24.575
# Epoch 25, lr 0.00085
# Epoch 25: Train 0.757, Test 0.910
# MSE NON-NORMALIZED: Train MSE 22.915, Test MSE 18.985
# Epoch 50, lr 0.00085
# Epoch 50: Train 0.730, Test 0.891
# MSE NON-NORMALIZED: Train MSE 21.544, Test MSE 18.624
# Epoch 75, lr 0.0002125
# Epoch 75: Train 0.658, Test 0.803
# MSE NON-NORMALIZED: Train MSE 17.753, Test MSE 23.262
# Epoch 100, lr 5.3125e-05
# Epoch 100: Train 0.637, Test 0.778
# MSE NON-NORMALIZED: Train MSE 17.325, Test MSE 28.589
# TRAINING MODEL dt_norm_1_25
# dt_norm_1_25
# /uscms/home/nswood/nobackup/Notebooks/AE_Dev/models/batched_models/CAE_combo_loss_250_150/dt_norm_1_25
# TRAINING INFO:
# Total Dataset Size: 40000
# Epoch 0, lr 0.00085
# Epoch 0: Train 1.184, Test 1.318
# MSE NON-NORMALIZED: Train MSE 38.528, Test MSE 31.057
# Epoch 25, lr 0.00085
# Epoch 25: Train 0.838, Test 0.905
# MSE NON-NORMALIZED: Train MSE 21.758, Test MSE 19.203
# Epoch 50, lr 0.000425
# Epoch 50: Train 0.755, Test 0.778
# MSE NON-NORMALIZED: Train MSE 17.060, Test MSE 16.443
# Epoch 75, lr 0.0002125
# Epoch 75: Train 0.713, Test 0.719
# MSE NON-NORMALIZED: Train MSE 15.992, Test MSE 22.691
# Epoch 100, lr 5.3125e-05
# Epoch 100: Train 0.703, Test 0.692
# MSE NON-NORMALIZED: Train MSE 15.685, Test MSE 27.898
# TRAINING MODEL dt_norm_1_27
# dt_norm_1_27
# /uscms/home/nswood/nobackup/Notebooks/AE_Dev/models/batched_models/CAE_combo_loss_250_150/dt_norm_1_27
# TRAINING INFO:
# Total Dataset Size: 40000
# Epoch 0, lr 0.00085
# Epoch 0: Train 0.496, Test 0.801
# MSE NON-NORMALIZED: Train MSE 18.335, Test MSE 17.163
# Epoch 25, lr 0.000425
# Epoch 25: Train 0.468, Test 0.513
# MSE NON-NORMALIZED: Train MSE 10.465, Test MSE 9.596
# Epoch 50, lr 0.00010625
# Epoch 50: Train 0.461, Test 0.485
# MSE NON-NORMALIZED: Train MSE 9.780, Test MSE 8.985
# Epoch 75, lr 2.65625e-05
# Epoch 75: Train 0.462, Test 0.483
# MSE NON-NORMALIZED: Train MSE 10.012, Test MSE 16.293
# Epoch 100, lr 3.3203125e-06
# Epoch 100: Train 0.463, Test 0.483
# MSE NON-NORMALIZED: Train MSE 10.314, Test MSE 22.611
# TRAINING MODEL dt_norm_1_29
# dt_norm_1_29
# /uscms/home/nswood/nobackup/Notebooks/AE_Dev/models/batched_models/CAE_combo_loss_250_150/dt_norm_1_29
# TRAINING INFO:
# Total Dataset Size: 40000
# Epoch 0, lr 0.00085
# Epoch 0: Train 0.806, Test 0.737
# MSE NON-NORMALIZED: Train MSE 27.866, Test MSE 16.922
# Epoch 25, lr 0.000425
# Epoch 25: Train 0.580, Test 0.785
# MSE NON-NORMALIZED: Train MSE 16.735, Test MSE 14.455
# Epoch 50, lr 0.0002125
# Epoch 50: Train 0.557, Test 0.705
# MSE NON-NORMALIZED: Train MSE 14.039, Test MSE 12.761
# Epoch 75, lr 5.3125e-05
# Epoch 75: Train 0.537, Test 0.688
# MSE NON-NORMALIZED: Train MSE 13.758, Test MSE 21.204
# Epoch 100, lr 1.328125e-05
# Epoch 100: Train 0.534, Test 0.683
# MSE NON-NORMALIZED: Train MSE 13.990, Test MSE 29.036
# TRAINING MODEL dt_norm_1_30
# dt_norm_1_30
# /uscms/home/nswood/nobackup/Notebooks/AE_Dev/models/batched_models/CAE_combo_loss_250_150/dt_norm_1_30
# TRAINING INFO:
# Total Dataset Size: 40000
# Epoch 0, lr 0.00085
# Epoch 0: Train 0.663, Test 0.662
# MSE NON-NORMALIZED: Train MSE 26.271, Test MSE 12.157
# Epoch 25, lr 0.0002125
# Epoch 25: Train 0.608, Test 0.542
# MSE NON-NORMALIZED: Train MSE 10.248, Test MSE 9.449
# Epoch 50, lr 5.3125e-05
# Epoch 50: Train 0.592, Test 0.522
# MSE NON-NORMALIZED: Train MSE 9.720, Test MSE 9.049
# Epoch 75, lr 1.328125e-05
# Epoch 75: Train 0.587, Test 0.516
# MSE NON-NORMALIZED: Train MSE 9.973, Test MSE 16.741
# Epoch 100, lr 3.3203125e-06
# Epoch 100: Train 0.583, Test 0.515
# MSE NON-NORMALIZED: Train MSE 10.307, Test MSE 23.845
# TRAINING MODEL dt_norm_1_31
# dt_norm_1_31
# /uscms/home/nswood/nobackup/Notebooks/AE_Dev/models/batched_models/CAE_combo_loss_250_150/dt_norm_1_31
# TRAINING INFO:
# Total Dataset Size: 40000
# Epoch 0, lr 0.00085
# Epoch 0: Train 1.118, Test 0.574
# MSE NON-NORMALIZED: Train MSE 38.884, Test MSE 13.203
# Epoch 25, lr 0.000425
# Epoch 25: Train 0.315, Test 0.508
# MSE NON-NORMALIZED: Train MSE 11.924, Test MSE 10.319
# Epoch 50, lr 0.0002125
# Epoch 50: Train 0.257, Test 0.455
# MSE NON-NORMALIZED: Train MSE 9.535, Test MSE 8.538
# Epoch 75, lr 5.3125e-05
# Epoch 75: Train 0.242, Test 0.444
# MSE NON-NORMALIZED: Train MSE 9.132, Test MSE 15.776
# Epoch 100, lr 1.328125e-05
# Epoch 100: Train 0.241, Test 0.443
# MSE NON-NORMALIZED: Train MSE 9.373, Test MSE 22.344
# TRAINING MODEL dt_norm_1_32
# dt_norm_1_32
# /uscms/home/nswood/nobackup/Notebooks/AE_Dev/models/batched_models/CAE_combo_loss_250_150/dt_norm_1_32
# TRAINING INFO:
# Total Dataset Size: 40000
# Epoch 0, lr 0.00085
# Epoch 0: Train 1.715, Test 0.546
# MSE NON-NORMALIZED: Train MSE 18.330, Test MSE 11.992
# Epoch 25, lr 0.000425
# Epoch 25: Train 0.540, Test 0.508
# MSE NON-NORMALIZED: Train MSE 10.169, Test MSE 8.808
# Epoch 50, lr 0.00010625
# Epoch 50: Train 0.526, Test 0.468
# MSE NON-NORMALIZED: Train MSE 8.671, Test MSE 8.123
# Epoch 75, lr 5.3125e-05
# Epoch 75: Train 0.474, Test 0.457
# MSE NON-NORMALIZED: Train MSE 8.509, Test MSE 13.879
# Epoch 100, lr 6.640625e-06
# Epoch 100: Train 0.469, Test 0.456
# MSE NON-NORMALIZED: Train MSE 8.698, Test MSE 19.256
# TRAINING MODEL dt_norm_1_33
# dt_norm_1_33
# /uscms/home/nswood/nobackup/Notebooks/AE_Dev/models/batched_models/CAE_combo_loss_250_150/dt_norm_1_33
# TRAINING INFO:
# Total Dataset Size: 40000
# Epoch 0, lr 0.00085
# Epoch 0: Train 0.489, Test 0.493
# MSE NON-NORMALIZED: Train MSE 13.395, Test MSE 9.214
# Epoch 25, lr 0.0002125
# Epoch 25: Train 0.535, Test 0.522
# MSE NON-NORMALIZED: Train MSE 9.551, Test MSE 8.818
# Epoch 50, lr 5.3125e-05
# Epoch 50: Train 0.494, Test 0.465
# MSE NON-NORMALIZED: Train MSE 8.221, Test MSE 7.754
# Epoch 75, lr 1.328125e-05
# Epoch 75: Train 0.491, Test 0.461
# MSE NON-NORMALIZED: Train MSE 8.351, Test MSE 13.044
# Epoch 100, lr 3.3203125e-06
# Epoch 100: Train 0.492, Test 0.461
# MSE NON-NORMALIZED: Train MSE 8.581, Test MSE 17.836
# TRAINING MODEL dt_norm_2_1
# dt_norm_2_1
# /uscms/home/nswood/nobackup/Notebooks/AE_Dev/models/batched_models/CAE_combo_loss_250_150/dt_norm_2_1
# TRAINING INFO:
# Total Dataset Size: 4013
# Epoch 0, lr 0.00085
# Epoch 0: Train 3.673, Test 6.521
# MSE NON-NORMALIZED: Train MSE 189.790, Test MSE 180.402
# Epoch 25, lr 0.00085
# Epoch 25: Train 1.994, Test 2.837
# MSE NON-NORMALIZED: Train MSE 82.403, Test MSE 89.465
# Epoch 50, lr 0.00085
# Epoch 50: Train 0.968, Test 0.923
# MSE NON-NORMALIZED: Train MSE 37.874, Test MSE 35.347
# Epoch 75, lr 0.0002125
# Epoch 75: Train 0.917, Test 0.762
# MSE NON-NORMALIZED: Train MSE 32.642, Test MSE 35.686
# Epoch 100, lr 0.00010625
# Epoch 100: Train 0.899, Test 0.739
# MSE NON-NORMALIZED: Train MSE 32.723, Test MSE 38.443
# TRAINING MODEL dt_norm_2_3
# dt_norm_2_3
# /uscms/home/nswood/nobackup/Notebooks/AE_Dev/models/batched_models/CAE_combo_loss_250_150/dt_norm_2_3
# TRAINING INFO:
# Total Dataset Size: 40000
# Epoch 0, lr 0.00085
# Epoch 0: Train 6.535, Test 7.716
# MSE NON-NORMALIZED: Train MSE 398.642, Test MSE 230.563
# Epoch 25, lr 0.00085
# Epoch 25: Train 4.401, Test 4.752
# MSE NON-NORMALIZED: Train MSE 161.369, Test MSE 139.511
# Epoch 50, lr 0.00085
# Epoch 50: Train 4.093, Test 4.183
# MSE NON-NORMALIZED: Train MSE 133.357, Test MSE 120.926
# Epoch 75, lr 0.0002125
# Epoch 75: Train 3.617, Test 3.702
# MSE NON-NORMALIZED: Train MSE 112.123, Test MSE 137.707
# Epoch 100, lr 5.3125e-05
# Epoch 100: Train 3.559, Test 3.640
# MSE NON-NORMALIZED: Train MSE 108.570, Test MSE 164.055
# TRAINING MODEL dt_norm_2_5
# dt_norm_2_5
# /uscms/home/nswood/nobackup/Notebooks/AE_Dev/models/batched_models/CAE_combo_loss_250_150/dt_norm_2_5
# TRAINING INFO:
# Total Dataset Size: 40000
# Epoch 0, lr 0.00085
# Epoch 0: Train 11.338, Test 13.127
# MSE NON-NORMALIZED: Train MSE 591.406, Test MSE 553.896
# Epoch 25, lr 0.00085
# Epoch 25: Train 6.933, Test 7.989
# MSE NON-NORMALIZED: Train MSE 360.210, Test MSE 290.244
# Epoch 50, lr 0.00085
# Epoch 50: Train 8.036, Test 7.142
# MSE NON-NORMALIZED: Train MSE 300.556, Test MSE 260.817
# Epoch 75, lr 0.0002125
# Epoch 75: Train 5.426, Test 5.342
# MSE NON-NORMALIZED: Train MSE 272.024, Test MSE 221.808
# Epoch 100, lr 0.00010625
# Epoch 100: Train 5.131, Test 3.967
# MSE NON-NORMALIZED: Train MSE 147.963, Test MSE 189.389
# TRAINING MODEL dt_norm_2_7
# dt_norm_2_7
# /uscms/home/nswood/nobackup/Notebooks/AE_Dev/models/batched_models/CAE_combo_loss_250_150/dt_norm_2_7
# TRAINING INFO:
# Total Dataset Size: 40000
# Epoch 0, lr 0.00085
# Epoch 0: Train 11.663, Test 16.750
# MSE NON-NORMALIZED: Train MSE 1055.100, Test MSE 1124.211
# Epoch 25, lr 0.000425
# Epoch 25: Train 4.273, Test 7.758
# MSE NON-NORMALIZED: Train MSE 459.401, Test MSE 413.809
# Epoch 50, lr 0.0002125
# Epoch 50: Train 3.149, Test 6.360
# MSE NON-NORMALIZED: Train MSE 397.316, Test MSE 318.027
# Epoch 75, lr 0.00010625
# Epoch 75: Train 3.015, Test 4.157
# MSE NON-NORMALIZED: Train MSE 316.473, Test MSE 230.346
# Epoch 100, lr 5.3125e-05
# Epoch 100: Train 2.617, Test 3.815
# MSE NON-NORMALIZED: Train MSE 202.547, Test MSE 249.479
# TRAINING MODEL dt_norm_2_9
# dt_norm_2_9
# /uscms/home/nswood/nobackup/Notebooks/AE_Dev/models/batched_models/CAE_combo_loss_250_150/dt_norm_2_9
# TRAINING INFO:
# Total Dataset Size: 40000
# Epoch 0, lr 0.00085
# Epoch 0: Train 7.191, Test 8.939
# MSE NON-NORMALIZED: Train MSE 607.820, Test MSE 437.121
# Epoch 25, lr 0.000425
# Epoch 25: Train 4.891, Test 6.678
# MSE NON-NORMALIZED: Train MSE 519.183, Test MSE 266.594
# Epoch 50, lr 0.000425
# Epoch 50: Train 12.613, Test 7.021
# MSE NON-NORMALIZED: Train MSE 587.369, Test MSE 336.964
# Epoch 75, lr 0.00010625
# Epoch 75: Train 4.214, Test 3.889
# MSE NON-NORMALIZED: Train MSE 193.150, Test MSE 186.649
# Epoch 100, lr 2.65625e-05
# Epoch 100: Train 2.294, Test 3.088
# MSE NON-NORMALIZED: Train MSE 165.060, Test MSE 187.336
# TRAINING MODEL dt_norm_2_11
# dt_norm_2_11
# /uscms/home/nswood/nobackup/Notebooks/AE_Dev/models/batched_models/CAE_combo_loss_250_150/dt_norm_2_11
# TRAINING INFO:
# Total Dataset Size: 40000
# Epoch 0, lr 0.00085
# Epoch 0: Train 4.978, Test 8.140
# MSE NON-NORMALIZED: Train MSE 345.061, Test MSE 351.708
# Epoch 25, lr 0.00085
# Epoch 25: Train 2.329, Test 4.389
# MSE NON-NORMALIZED: Train MSE 235.077, Test MSE 162.773
# Epoch 50, lr 0.00085
# Epoch 50: Train 3.504, Test 5.930
# MSE NON-NORMALIZED: Train MSE 201.944, Test MSE 219.523
# Epoch 75, lr 0.00010625
# Epoch 75: Train 2.188, Test 4.831
# MSE NON-NORMALIZED: Train MSE 324.581, Test MSE 201.482
# Epoch 100, lr 2.65625e-05
# Epoch 100: Train 1.648, Test 2.470
# MSE NON-NORMALIZED: Train MSE 101.219, Test MSE 141.129
# TRAINING MODEL dt_norm_2_13
# dt_norm_2_13
# /uscms/home/nswood/nobackup/Notebooks/AE_Dev/models/batched_models/CAE_combo_loss_250_150/dt_norm_2_13
# TRAINING INFO:
# Total Dataset Size: 40000
# Epoch 0, lr 0.00085
# Epoch 0: Train 7.942, Test 4.742
# MSE NON-NORMALIZED: Train MSE 149.913, Test MSE 162.839
# Epoch 25, lr 0.00085
# Epoch 25: Train 8.203, Test 6.249
# MSE NON-NORMALIZED: Train MSE 274.111, Test MSE 212.500
# Epoch 50, lr 0.000425
# Epoch 50: Train 3.938, Test 2.909
# MSE NON-NORMALIZED: Train MSE 77.648, Test MSE 83.424
# Epoch 75, lr 0.0002125
# Epoch 75: Train 2.463, Test 1.744
# MSE NON-NORMALIZED: Train MSE 57.027, Test MSE 71.172
# Epoch 100, lr 5.3125e-05
# Epoch 100: Train 2.428, Test 1.729
# MSE NON-NORMALIZED: Train MSE 56.712, Test MSE 89.909
# TRAINING MODEL dt_norm_2_15
# dt_norm_2_15
# /uscms/home/nswood/nobackup/Notebooks/AE_Dev/models/batched_models/CAE_combo_loss_250_150/dt_norm_2_15
# TRAINING INFO:
# Total Dataset Size: 40000
# Epoch 0, lr 0.00085
# Epoch 0: Train 1.883, Test 3.263
# MSE NON-NORMALIZED: Train MSE 80.918, Test MSE 89.893
# Epoch 25, lr 0.00085
# Epoch 25: Train 1.353, Test 2.172
# MSE NON-NORMALIZED: Train MSE 52.681, Test MSE 57.159
# Epoch 50, lr 0.000425
# Epoch 50: Train 1.244, Test 1.547
# MSE NON-NORMALIZED: Train MSE 38.362, Test MSE 39.492
# Epoch 75, lr 0.0002125
# Epoch 75: Train 1.203, Test 1.453
# MSE NON-NORMALIZED: Train MSE 38.315, Test MSE 53.258
# Epoch 100, lr 2.65625e-05
# Epoch 100: Train 1.184, Test 1.409
# MSE NON-NORMALIZED: Train MSE 38.642, Test MSE 68.108
# TRAINING MODEL dt_norm_2_17
# dt_norm_2_17
# /uscms/home/nswood/nobackup/Notebooks/AE_Dev/models/batched_models/CAE_combo_loss_250_150/dt_norm_2_17
# TRAINING INFO:
# Total Dataset Size: 40000
# Epoch 0, lr 0.00085
# Epoch 0: Train 3.081, Test 2.546
# MSE NON-NORMALIZED: Train MSE 157.382, Test MSE 110.064
# Epoch 25, lr 0.00085
# Epoch 25: Train 1.973, Test 1.624
# MSE NON-NORMALIZED: Train MSE 42.297, Test MSE 39.125
# Epoch 50, lr 0.000425
# Epoch 50: Train 1.584, Test 1.239
# MSE NON-NORMALIZED: Train MSE 31.391, Test MSE 29.866
# Epoch 75, lr 0.0002125
# Epoch 75: Train 1.543, Test 1.187
# MSE NON-NORMALIZED: Train MSE 30.266, Test MSE 43.703
# Epoch 100, lr 2.65625e-05
# Epoch 100: Train 1.538, Test 1.181
# MSE NON-NORMALIZED: Train MSE 30.429, Test MSE 58.205
# TRAINING MODEL dt_norm_2_19
# dt_norm_2_19
# /uscms/home/nswood/nobackup/Notebooks/AE_Dev/models/batched_models/CAE_combo_loss_250_150/dt_norm_2_19
# TRAINING INFO:
# Total Dataset Size: 40000
# Epoch 0, lr 0.00085
# Epoch 0: Train 5.638, Test 4.895
# MSE NON-NORMALIZED: Train MSE 115.534, Test MSE 197.638
# Epoch 25, lr 0.00085
# Epoch 25: Train 3.121, Test 1.740
# MSE NON-NORMALIZED: Train MSE 64.834, Test MSE 58.206
# Epoch 50, lr 0.000425
# Epoch 50: Train 2.469, Test 1.482
# MSE NON-NORMALIZED: Train MSE 42.956, Test MSE 43.199
# Epoch 75, lr 0.00010625
# Epoch 75: Train 2.425, Test 1.412
# MSE NON-NORMALIZED: Train MSE 41.442, Test MSE 54.715
# Epoch 100, lr 1.328125e-05
# Epoch 100: Train 2.418, Test 1.402
# MSE NON-NORMALIZED: Train MSE 41.875, Test MSE 68.572
# TRAINING MODEL dt_norm_2_21
# dt_norm_2_21
# /uscms/home/nswood/nobackup/Notebooks/AE_Dev/models/batched_models/CAE_combo_loss_250_150/dt_norm_2_21
# TRAINING INFO:
# Total Dataset Size: 40000
# Epoch 0, lr 0.00085
# Epoch 0: Train 1.777, Test 2.138
# MSE NON-NORMALIZED: Train MSE 72.020, Test MSE 64.952
# Epoch 25, lr 0.00085
# Epoch 25: Train 1.147, Test 1.208
# MSE NON-NORMALIZED: Train MSE 36.826, Test MSE 34.563
# Epoch 50, lr 0.00085
# Epoch 50: Train 1.156, Test 1.138
# MSE NON-NORMALIZED: Train MSE 34.261, Test MSE 32.520
# Epoch 75, lr 0.000425
# Epoch 75: Train 1.050, Test 1.097
# MSE NON-NORMALIZED: Train MSE 32.939, Test MSE 44.830
# Epoch 100, lr 0.00010625
# Epoch 100: Train 1.039, Test 1.087
# MSE NON-NORMALIZED: Train MSE 33.003, Test MSE 57.374
# TRAINING MODEL dt_norm_2_23
# dt_norm_2_23
# /uscms/home/nswood/nobackup/Notebooks/AE_Dev/models/batched_models/CAE_combo_loss_250_150/dt_norm_2_23
# TRAINING INFO:
# Total Dataset Size: 35691
# Epoch 0, lr 0.00085
# Epoch 0: Train 7.570, Test 2.380
# MSE NON-NORMALIZED: Train MSE 109.470, Test MSE 84.832
# Epoch 25, lr 0.00085
# Epoch 25: Train 7.605, Test 3.450
# MSE NON-NORMALIZED: Train MSE 114.720, Test MSE 108.303
# Epoch 50, lr 0.00085
# Epoch 50: Train 7.375, Test 2.061
# MSE NON-NORMALIZED: Train MSE 75.013, Test MSE 71.717
# Epoch 75, lr 0.000425
# Epoch 75: Train 7.338, Test 1.941
# MSE NON-NORMALIZED: Train MSE 71.367, Test MSE 82.149
# Epoch 100, lr 0.00010625
# Epoch 100: Train 7.313, Test 1.858
# MSE NON-NORMALIZED: Train MSE 68.305, Test MSE 90.394
# TRAINING MODEL dt_norm_2_25
# dt_norm_2_25
# /uscms/home/nswood/nobackup/Notebooks/AE_Dev/models/batched_models/CAE_combo_loss_250_150/dt_norm_2_25
# TRAINING INFO:
# Total Dataset Size: 22067
# Epoch 0, lr 0.00085
# Epoch 0: Train 1.201, Test 1.846
# MSE NON-NORMALIZED: Train MSE 39.036, Test MSE 46.188
# Epoch 25, lr 0.000425
# Epoch 25: Train 0.390, Test 0.566
# MSE NON-NORMALIZED: Train MSE 13.275, Test MSE 11.234
# Epoch 50, lr 0.0002125
# Epoch 50: Train 0.362, Test 0.550
# MSE NON-NORMALIZED: Train MSE 12.079, Test MSE 10.915
# Epoch 75, lr 5.3125e-05
# Epoch 75: Train 0.357, Test 0.545
# MSE NON-NORMALIZED: Train MSE 12.279, Test MSE 17.712
# Epoch 100, lr 1.328125e-05
# Epoch 100: Train 0.357, Test 0.545
# MSE NON-NORMALIZED: Train MSE 12.659, Test MSE 23.849
# TRAINING MODEL dt_norm_2_27
# dt_norm_2_27
# /uscms/home/nswood/nobackup/Notebooks/AE_Dev/models/batched_models/CAE_combo_loss_250_150/dt_norm_2_27
# TRAINING INFO:
# Total Dataset Size: 19241
# Epoch 0, lr 0.00085
# Epoch 0: Train 0.559, Test 0.914
# MSE NON-NORMALIZED: Train MSE 22.861, Test MSE 21.630
# Epoch 25, lr 0.00085
# Epoch 25: Train 0.391, Test 0.595
# MSE NON-NORMALIZED: Train MSE 13.653, Test MSE 13.120
# Epoch 50, lr 0.000425
# Epoch 50: Train 0.360, Test 0.551
# MSE NON-NORMALIZED: Train MSE 12.307, Test MSE 11.931
# Epoch 75, lr 0.0002125
# Epoch 75: Train 0.295, Test 0.418
# MSE NON-NORMALIZED: Train MSE 9.594, Test MSE 13.121
# Epoch 100, lr 5.3125e-05
# Epoch 100: Train 0.291, Test 0.416
# MSE NON-NORMALIZED: Train MSE 9.770, Test MSE 16.658
# TRAINING MODEL dt_norm_2_29
# dt_norm_2_29
# /uscms/home/nswood/nobackup/Notebooks/AE_Dev/models/batched_models/CAE_combo_loss_250_150/dt_norm_2_29
# TRAINING INFO:
# Total Dataset Size: 36516
# Epoch 0, lr 0.00085
# Epoch 0: Train 0.413, Test 0.528
# MSE NON-NORMALIZED: Train MSE 14.395, Test MSE 10.676
# Epoch 50, lr 5.3125e-05
# Epoch 50: Train 0.382, Test 0.384
# MSE NON-NORMALIZED: Train MSE 7.818, Test MSE 6.283
# Epoch 75, lr 1.328125e-05
# Epoch 75: Train 0.381, Test 0.382
# MSE NON-NORMALIZED: Train MSE 7.805, Test MSE 9.536
# Epoch 100, lr 3.3203125e-06
# Epoch 100: Train 0.383, Test 0.383
# MSE NON-NORMALIZED: Train MSE 7.922, Test MSE 12.218
# TRAINING MODEL dt_norm_2_30
# dt_norm_2_30
# /uscms/home/nswood/nobackup/Notebooks/AE_Dev/models/batched_models/CAE_combo_loss_250_150/dt_norm_2_30
# TRAINING INFO:
# Total Dataset Size: 25249
# Epoch 0, lr 0.00085
# Epoch 0: Train 0.788, Test 9.602
# MSE NON-NORMALIZED: Train MSE 30.965, Test MSE 530.730
# Epoch 25, lr 0.00085
# Epoch 25: Train 0.305, Test 0.546
# MSE NON-NORMALIZED: Train MSE 10.046, Test MSE 11.616
# Epoch 50, lr 0.000425
# Epoch 50: Train 0.230, Test 0.318
# MSE NON-NORMALIZED: Train MSE 6.321, Test MSE 5.757
# Epoch 75, lr 0.00010625
# Epoch 75: Train 0.224, Test 0.304
# MSE NON-NORMALIZED: Train MSE 6.004, Test MSE 9.745
# Epoch 100, lr 2.65625e-05
# Epoch 100: Train 0.221, Test 0.290
# MSE NON-NORMALIZED: Train MSE 5.856, Test MSE 12.355
# TRAINING MODEL dt_norm_2_31
# dt_norm_2_31
# /uscms/home/nswood/nobackup/Notebooks/AE_Dev/models/batched_models/CAE_combo_loss_250_150/dt_norm_2_31
# TRAINING INFO:
# Total Dataset Size: 10026
# Epoch 0, lr 0.00085
# Epoch 0: Train 0.148, Test 0.308
# MSE NON-NORMALIZED: Train MSE 8.382, Test MSE 5.489
# Epoch 25, lr 0.0002125
# Epoch 25: Train 0.181, Test 0.206
# MSE NON-NORMALIZED: Train MSE 3.463, Test MSE 3.196
# Epoch 50, lr 0.00010625
# Epoch 50: Train 0.166, Test 0.193
# MSE NON-NORMALIZED: Train MSE 3.201, Test MSE 2.940
# Epoch 75, lr 2.65625e-05
# Epoch 75: Train 0.168, Test 0.193
# MSE NON-NORMALIZED: Train MSE 3.280, Test MSE 3.901
# Epoch 100, lr 6.640625e-06
# Epoch 100: Train 0.169, Test 0.195
# MSE NON-NORMALIZED: Train MSE 3.343, Test MSE 4.274
# TRAINING MODEL dt_norm_2_32
# dt_norm_2_32
# /uscms/home/nswood/nobackup/Notebooks/AE_Dev/models/batched_models/CAE_combo_loss_250_150/dt_norm_2_32
# TRAINING INFO:
# Total Dataset Size: 8412
# Epoch 0, lr 0.00085
# Epoch 0: Train 0.277, Test 0.267
# MSE NON-NORMALIZED: Train MSE 4.676, Test MSE 4.269
# Epoch 25, lr 0.00085
# Epoch 25: Train 0.188, Test 0.188
# MSE NON-NORMALIZED: Train MSE 3.036, Test MSE 2.784
# Epoch 50, lr 0.00085
# Epoch 50: Train 0.173, Test 0.185
# MSE NON-NORMALIZED: Train MSE 2.985, Test MSE 2.742
# Epoch 75, lr 0.00085
# Epoch 75: Train 0.162, Test 0.184
# MSE NON-NORMALIZED: Train MSE 3.052, Test MSE 3.536
# Epoch 100, lr 0.000425
# Epoch 100: Train 0.150, Test 0.182
# MSE NON-NORMALIZED: Train MSE 3.041, Test MSE 3.865
# TRAINING MODEL dt_norm_2_34
# dt_norm_2_34
# /uscms/home/nswood/nobackup/Notebooks/AE_Dev/models/batched_models/CAE_combo_loss_250_150/dt_norm_2_34
# TRAINING INFO:
# Total Dataset Size: 40000
# Epoch 0, lr 0.00085
# Epoch 0: Train 0.398, Test 0.568
# MSE NON-NORMALIZED: Train MSE 38.694, Test MSE 10.710
# Epoch 25, lr 0.00085
# Epoch 25: Train 0.344, Test 0.490
# MSE NON-NORMALIZED: Train MSE 9.512, Test MSE 8.646
# Epoch 50, lr 0.000425
# Epoch 50: Train 0.327, Test 0.428
# MSE NON-NORMALIZED: Train MSE 7.856, Test MSE 7.372
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [10], line 2
#       1 importlib.reload(train_CAE)
# ----> 2 train_CAE.train_CAEs(data_path,
#       3               dt_files,
#       4                model_params = [],
#       5               override = True ,
#       6               loss = combo_loss,
#       7               path_1 = 'models/CAE_Models/dt_1_250_150',
#       8               path_2 = 'models/CAE_Models/dt_2_250_150',
#       9               path_3 = 'models/CAE_Models/dt_3_250_150',
#      10              dir_label ='CAE_combo_loss_250_150',
#      11              epochs= 101,
#      12              batch = 20,
#      13              lr = 8.5e-4)
#
# File /uscms_data/d3/nswood/Notebooks/AE_Dev/train_CAE.py:224, in train_CAEs(data_path, dt_files, batch, override, model_params, loss, path_1, path_2, path_3, append_ReLU, max_dt_size, epochs, lr, dir_label, path)
#     222 print(params[1].name)
#     223 print(os.path.join(path,params[1].name))
# --> 224 train_CAE(params[0].to(device),
#     225           params[1].dt_train.to(device),
#     226           params[1].dt_test.to(device),
#     227           params[1].name,
#     228           os.path.join(path,params[1].name),
#     229           path = path,batch = batch, num_epochs = epochs, lr = lr)
#     230 #clear cuda after training each model
#     231 torch.cuda.empty_cache()
#
# File /uscms_data/d3/nswood/Notebooks/AE_Dev/train_CAE.py:101, in train_CAE(model, train, test, label, cur_directory, path, loss, num_epochs, lr, batch)
#      98 for i, (data,sum_TC) in enumerate(train_d1_flat):
#     100     model.train()
# --> 101     v_pred = model(data,sum_TC)
#     102     batch_loss = loss(data[:,0:48], v_pred,epoch,mean,std)
#     103     all_train_losses.append(batch_loss.item())
#
# File /uscms_data/d3/nswood/mambaforge/envs/myenv/lib/python3.10/site-packages/torch/nn/modules/module.py:1190, in Module._call_impl(self, *input, **kwargs)
#    1186 # If we don't have any hooks, we want to skip the rest of the logic in
#    1187 # this function, and just call forward.
#    1188 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190     return forward_call(*input, **kwargs)
#    1191 # Do not call functions when jit is used
#    1192 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /uscms_data/d3/nswood/Notebooks/AE_Dev/Naive_DAE.py:59, in CAE.forward(self, x, c)
#      45 """Forward step
#      46
#      47 Parameters
#    (...)
#      56
#      57 """
#      58 x_encoded = self.encode(x)
# ---> 59 x_reconstructed = self.decode(x_encoded,c)
#      60 return x_reconstructed
#
# File /uscms_data/d3/nswood/Notebooks/AE_Dev/Naive_DAE.py:102, in CAE.decode(self, x, c)
#     100 x = torch.hstack([x,c])
#     101 for dec in self.decoders:
# --> 102     x = dec(x)
#     103 return x
#
# File /uscms_data/d3/nswood/mambaforge/envs/myenv/lib/python3.10/site-packages/torch/nn/modules/module.py:1190, in Module._call_impl(self, *input, **kwargs)
#    1186 # If we don't have any hooks, we want to skip the rest of the logic in
#    1187 # this function, and just call forward.
#    1188 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190     return forward_call(*input, **kwargs)
#    1191 # Do not call functions when jit is used
#    1192 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /uscms_data/d3/nswood/mambaforge/envs/myenv/lib/python3.10/site-packages/torch/nn/modules/linear.py:114, in Linear.forward(self, input)
#     113 def forward(self, input: Tensor) -> Tensor:
# --> 114     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %%
import CAE_generate_stats

# %%
import CAE_generate_stats
importlib.reload(CAE_generate_stats)

CAE_generate_stats.gen_batch_stats("models/batched_models/test_CAE",
                                  data_path
                                  )
# Out:
# /uscms_data/d3/nswood/Notebooks/AE_Dev/CAE_generate_stats.py:28: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   all_data.append(torch.tensor(data[-dt_size:]))
# /uscms_data/d3/nswood/Notebooks/AE_Dev/CAE_generate_stats.py:29: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   all_pred.append(torch.tensor(pred[-dt_size:]))
# MSE 0.5937594175338745
# Median 0.2135574072599411
# Standard Devitaion 2.0383644104003906
# Average std error 1.2838290929794312
# Average % Error of Energy Reconstruction nan
